# %% [markdown]
# 2203A51499

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, Dense, Dropout
from tensorflow.keras import Sequential, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""

vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts([text])

sequences = tokenizer.texts_to_sequences([text])[0]

input_sequences = []
for i in range(1, len(sequences)):
    input_sequences.append(sequences[:i+1])

max_sequence_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')

X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)

class TransformerModel(Model):
    def __init__(self, vocab_size, embed_dim, num_heads, ff_dim):
        super(TransformerModel, self).__init__()
        self.embedding = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = Sequential([Dense(ff_dim, activation="relu"), Dense(embed_dim)])
        self.layernorm1 = LayerNormalization()
        self.layernorm2 = LayerNormalization()
        self.dropout1 = Dropout(0.1)
        self.dropout2 = Dropout(0.1)
        self.final_layer = Dense(vocab_size, activation="softmax")

    def call(self, inputs):
        x = self.embedding(inputs)
        attn_output = self.attention(x, x)
        x = self.layernorm1(x + self.dropout1(attn_output))
        ffn_output = self.dense_proj(x)
        x = self.layernorm2(x + self.dropout2(ffn_output))

        return self.final_layer(x[:, -1])

embed_dim = 128
num_heads = 4
ff_dim = 512

transformer_model = TransformerModel(vocab_size, embed_dim, num_heads, ff_dim)
transformer_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

epochs_list = [20,60,70]
for epochs in epochs_list:
    print(f"\nTraining model with {epochs} epochs:")
    transformer_model.fit(X, y, epochs=epochs, verbose=1)

def generate_text(model, tokenizer, seed_text, max_length=50):
    for _ in range(max_length):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=-1).item()
        output_word = tokenizer.index_word.get(predicted_word_index, "")
        seed_text += " " + output_word
    return seed_text

seed_text = "Once upon a time"
print("\nGenerated text:", generate_text(transformer_model, tokenizer, seed_text))
# Out:
# Training model with 20 epochs:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.0000e+00 - loss: 7.0967
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.1508 - loss: 6.0400
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.1958 - loss: 5.4011
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.1767 - loss: 4.9393
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.2634 - loss: 4.3226
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.4523 - loss: 3.8893
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.7261 - loss: 3.4244
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.7816 - loss: 2.9795
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.8475 - loss: 2.5373
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8025 - loss: 2.2179
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7712 - loss: 1.9971
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.7816 - loss: 1.7261
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8163 - loss: 1.5254
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8267 - loss: 1.2404
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8250 - loss: 1.1131
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8475 - loss: 0.9618
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8405 - loss: 0.9458
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8509 - loss: 0.8327
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8839 - loss: 0.7712
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.8284 - loss: 0.6812
#
# Training model with 60 epochs:
# Epoch 1/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8388 - loss: 0.6477
# Epoch 2/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.8527 - loss: 0.6174
# Epoch 3/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.8735 - loss: 0.5712
# Epoch 4/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.8839 - loss: 0.5283
# Epoch 5/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.8977 - loss: 0.5035
# Epoch 6/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.9186 - loss: 0.4736
# Epoch 7/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.8960 - loss: 0.4488
# Epoch 8/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.9186 - loss: 0.4053
# Epoch 9/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9081 - loss: 0.3896
# Epoch 10/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.9081 - loss: 0.3901
# Epoch 11/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9081 - loss: 0.3828
# Epoch 12/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9411 - loss: 0.3294
# Epoch 13/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.9411 - loss: 0.3429
# Epoch 14/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.9307 - loss: 0.3390
# Epoch 15/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9428 - loss: 0.3214
# Epoch 16/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.9532 - loss: 0.2996
# Epoch 17/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.9307 - loss: 0.2887
# Epoch 18/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9411 - loss: 0.2733
# Epoch 19/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - accuracy: 0.9532 - loss: 0.2596
# Epoch 20/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.9636 - loss: 0.2241
# Epoch 21/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.9324 - loss: 0.2750
# Epoch 22/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9186 - loss: 0.2344
# Epoch 23/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9532 - loss: 0.2175
# Epoch 24/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9411 - loss: 0.2204
# Epoch 25/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.9428 - loss: 0.2159
# Epoch 26/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.9532 - loss: 0.2183
# Epoch 27/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.9636 - loss: 0.1877
# Epoch 28/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9411 - loss: 0.1855
# Epoch 29/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.